# %% [markdown]
# # Data science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
# - List popular languages for data scientists
# - List Data Science Tools
# - Evaluate basic arethmic expressions
# - Write basic functions, such as the conversion of minutes to hours

# %% [markdown]
# Some of the more popular languages that Data Scientists use are
# 1. R
# 2. Python
# 3. SQL
# 4. Java
# 5. Scala
# 6. Javascript

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# - Pandas
# - Numpy
# - Matplotlib
# - Seaborn
# - pytorch
# - ggplot
# - Dplyr
# - keras
# - tensorflow

# %% [markdown]
# |Data Science Tools|
# |:----|
# |Jupyter|
# |Rstudio|
# |Spyder|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
(3*4)+5
# This is a simple arithmetic expression to multiply then add integers
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.

minutes = 200
hours = minutes/60
print(minutes,"minutes is ",hours," hours")
# Out:
# 200 minutes is  3.3333333333333335  hours

# %% [markdown]
# ## Author
# Stijn de Vries

# %% [markdown]
# ![2-title.png](attachment:2-title.png)

# %% [markdown]
# ![3-intro.png](attachment:3-intro.png)

# %% [markdown]
# ![4-dslanguages.png](attachment:4-dslanguages.png)

# %% [markdown]
# ![5-dslibraries.png](attachment:5-dslibraries.png)

# %% [markdown]
# ![6_dstools.png](attachment:6_dstools.png)

# %% [markdown]
# ![7_introarithmetic.png](attachment:7_introarithmetic.png)

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:8-multiplyandaddintegers.png)

# %% [markdown]
# ![9-hourstominutes.png](attachment:9-hourstominutes.png)

# %% [markdown]
# ![10-objectives.png](attachment:10-objectives.png)

# %% [markdown]
# ![11-authordetails.png](attachment:11-authordetails.png)
